# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries: THis is a change.

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='weather' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[42.359194,-71.092877] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='5mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=20


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:55 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/sV1ef7n9kQ',
#      'expanded_url': 'https://twitter.com/JTaylor_16x/status/839542964879753216/photo/1',
#      'id': 839542957741129730,
#      'id_str': '839542957741129730',
#      'indices': [67, 90],
#      'media_url': 'http://pbs.twimg.com/media/C6an3znXQAITHzD.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6an3znXQAITHzD.jpg',
#      'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1152},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 383},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/sV1ef7n9kQ'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/sV1ef7n9kQ',
#      'expanded_url': 'https://twitter.com/JTaylor_16x/status/839542964879753216/photo/1',
#      'id': 839542957741129730,
#      'id_str': '839542957741129730',
#      'indices': [67, 90],
#      'media_url': 'http://pbs.twimg.com/media/C6an3znXQAITHzD.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6an3znXQAITHzD.jpg',
#      'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1152},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 383},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/sV1ef7n9kQ'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542964879753216,
#   'id_str': '839542964879753216',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Could you not decide weather you wanted a monobrow today or not?😭😂 https://t.co/sV1ef7n9kQ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Dec 26 00:02:30 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "#FREEKHAZRI // Sunderland AFC. Views are my own👀. It's not about where you start, it's about where you finish👊🏼",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'freekhazri.com',
#        'expanded_url': 'http://www.freekhazri.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/PI0MA4RxlH'}]}},
#    'favourites_count': 29364,
#    'follow_request_sent': None,
#    'followers_count': 345,
#    'following': None,
#    'friends_count': 646,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 4605164866,
#    'id_str': '4605164866',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en-GB',
#    'listed_count': 5,
#    'location': 'Sunderland, England',
#    'name': 'JT🤙🏼',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4605164866/1481581972',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832500552609173504/9go7OkDB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832500552609173504/9go7OkDB_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JTaylor_16x',
#    'statuses_count': 8558,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/PI0MA4RxlH',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:55 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/VFAGUwy8TG',
#      'expanded_url': 'https://twitter.com/adriaannnr/status/839457434867548160/photo/1',
#      'id': 839457431629496320,
#      'id_str': '839457431629496320',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#      'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 382},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 839457434867548160,
#      'source_status_id_str': '839457434867548160',
#      'source_user_id': 3400809335,
#      'source_user_id_str': '3400809335',
#      'type': 'photo',
#      'url': 'https://t.co/VFAGUwy8TG'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3400809335,
#      'id_str': '3400809335',
#      'indices': [3, 14],
#      'name': 'A🅱️oogiewitDaHoodie',
#      'screen_name': 'adriaannnr'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/VFAGUwy8TG',
#      'expanded_url': 'https://twitter.com/adriaannnr/status/839457434867548160/photo/1',
#      'id': 839457431629496320,
#      'id_str': '839457431629496320',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#      'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 382},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 839457434867548160,
#      'source_status_id_str': '839457434867548160',
#      'source_user_id': 3400809335,
#      'source_user_id_str': '3400809335',
#      'type': 'photo',
#      'url': 'https://t.co/VFAGUwy8TG'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542963990642689,
#   'id_str': '839542963990642689',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 52,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 08 12:47:03 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/VFAGUwy8TG',
#       'expanded_url': 'https://twitter.com/adriaannnr/status/839457434867548160/photo/1',
#       'id': 839457431629496320,
#       'id_str': '839457431629496320',
#       'indices': [39, 62],
#       'media_url': 'http://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/VFAGUwy8TG'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/VFAGUwy8TG',
#       'expanded_url': 'https://twitter.com/adriaannnr/status/839457434867548160/photo/1',
#       'id': 839457431629496320,
#       'id_str': '839457431629496320',
#       'indices': [39, 62],
#       'media_url': 'http://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6ZaFiBWgAA_Dl6.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/VFAGUwy8TG'}]},
#    'favorite_count': 39,
#    'favorited': False,
#    'geo': None,
#    'id': 839457434867548160,
#    'id_str': '839457434867548160',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 52,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'North Carolina weather at its finest 🙂 https://t.co/VFAGUwy8TG',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Aug 03 01:58:23 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Southeast Raleigh Football | 2016 1st Team All -Conference DE #19 | '17 https://t.co/SA3FkO9gLY 🇹🇹",
#     'entities': {'description': {'urls': [{'display_url': 'hudl.com/v/13Yz2r',
#         'expanded_url': 'http://www.hudl.com/v/13Yz2r',
#         'indices': [72, 95],
#         'url': 'https://t.co/SA3FkO9gLY'}]}},
#     'favourites_count': 1883,
#     'follow_request_sent': None,
#     'followers_count': 463,
#     'following': None,
#     'friends_count': 205,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 3400809335,
#     'id_str': '3400809335',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'in your backfield ',
#     'name': 'A🅱️oogiewitDaHoodie',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3400809335/1486590183',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/837689369511223296/kmJdEVS4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837689369511223296/kmJdEVS4_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'adriaannnr',
#     'statuses_count': 5113,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @adriaannnr: North Carolina weather at its finest 🙂 https://t.co/VFAGUwy8TG',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 02 16:47:11 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '👣✨',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 4613,
#    'follow_request_sent': None,
#    'followers_count': 368,
#    'following': None,
#    'friends_count': 225,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1142869740,
#    'id_str': '1142869740',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': '919',
#    'name': 'Alexandria 👸🏾✨',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142869740/1486001312',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/833659437080535040/2s6q9mrx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833659437080535040/2s6q9mrx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LeahAlexandria_',
#    'statuses_count': 5618,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:54 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/839542959821492225',
#      'indices': [117, 140],
#      'url': 'https://t.co/lHkHNogwoA'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542959821492225,
#   'id_str': '839542959821492225',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-92.452373, 31.3030963],
#       [-92.34801, 31.3030963],
#       [-92.34801, 31.384652],
#       [-92.452373, 31.384652]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Pineville, LA',
#    'id': 'a22746c88990f7a6',
#    'name': 'Pineville',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/a22746c88990f7a6.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "We are here in Pineville at Mac's Fresh Market for our weather radio event! Come on out and purchase one and we wil… https://t.co/lHkHNogwoA",
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Oct 12 02:03:47 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Weekend Meteorologist for @KALBtv5, @BallState Alum, Storm Chaser🌪, #Reds ⚾️, Cyclist 🚴🏼,Photographer📸. All opinions are my own',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'kalb.com/content/bios/3…',
#        'expanded_url': 'http://www.kalb.com/content/bios/368472591.html',
#        'indices': [0, 23],
#        'url': 'https://t.co/dQfg0CVC02'}]}},
#    'favourites_count': 4329,
#    'follow_request_sent': None,
#    'followers_count': 665,
#    'following': None,
#    'friends_count': 522,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 201534770,
#    'id_str': '201534770',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 32,
#    'location': 'Ft. Wayne, IN - Alexandria, LA',
#    'name': 'Adam Burniston',
#    'notifications': None,
#    'profile_background_color': '000203',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000092753594/090db89fbbe7d5f2c99038d995b37e7b.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000092753594/090db89fbbe7d5f2c99038d995b37e7b.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/201534770/1466556689',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827316999864852480/T4YuU5Wq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827316999864852480/T4YuU5Wq_normal.jpg',
#    'profile_link_color': '405FDB',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '050505',
#    'profile_text_color': 'F70808',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AdamBurnistonWX',
#    'statuses_count': 7694,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/dQfg0CVC02',
#    'utc_offset': -18000,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:51 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 6433472,
#      'id_str': '6433472',
#      'indices': [0, 8],
#      'name': 'CBC News',
#      'screen_name': 'CBCNews'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542946743664651,
#   'id_str': '839542946743664651',
#   'in_reply_to_screen_name': 'CBCNews',
#   'in_reply_to_status_id': 839536337309089794,
#   'in_reply_to_status_id_str': '839536337309089794',
#   'in_reply_to_user_id': 6433472,
#   'in_reply_to_user_id_str': '6433472',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': '@CBCNews what kinda women walks pregnant through sub zero weather and blizzards to illegally cross into another country! Economic migrants!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 05 01:43:21 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': True,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 445,
#    'follow_request_sent': None,
#    'followers_count': 12,
#    'following': None,
#    'friends_count': 89,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 828056382884679681,
#    'id_str': '828056382884679681',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Canada',
#    'name': 'R.J. Gallant',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'RJGallant09',
#    'statuses_count': 233,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:50 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542943853629440,
#   'id_str': '839542943853629440',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'I love the weather today',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 24 20:08:07 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'CCHS. Gabriel',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 4673,
#    'follow_request_sent': None,
#    'followers_count': 512,
#    'following': None,
#    'friends_count': 387,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1216443446,
#    'id_str': '1216443446',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': '',
#    'name': 'Marlene',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1216443446/1488314402',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837912850483949568/KlibyG-2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837912850483949568/KlibyG-2_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'marlene_calvo',
#    'statuses_count': 3245,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:49 +0000 2017',
#   'entities': {'hashtags': [{'indices': [90, 103], 'text': 'summitsafely'}],
#    'symbols': [],
#    'urls': [{'display_url': 'lakedistrictweatherline.co.uk/home',
#      'expanded_url': 'http://www.lakedistrictweatherline.co.uk/home',
#      'indices': [104, 127],
#      'url': 'https://t.co/mjeQuy6w5g'}],
#    'user_mentions': [{'id': 423490958,
#      'id_str': '423490958',
#      'indices': [3, 16],
#      'name': 'Fell Top Assessors',
#      'screen_name': 'LakesWeather'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542938518634502,
#   'id_str': '839542938518634502',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 18,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 08 17:27:23 +0000 2017',
#    'entities': {'hashtags': [{'indices': [72, 85], 'text': 'summitsafely'}],
#     'media': [{'display_url': 'pic.twitter.com/DSpiAmJbkj',
#       'expanded_url': 'https://twitter.com/LakesWeather/status/839527983874523146/photo/1',
#       'id': 839527865188237314,
#       'id_str': '839527865188237314',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/C6aaJTeWQAICDwN.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aaJTeWQAICDwN.jpg',
#       'sizes': {'large': {'h': 1500, 'resize': 'fit', 'w': 2000},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/DSpiAmJbkj'}],
#     'symbols': [],
#     'urls': [{'display_url': 'lakedistrictweatherline.co.uk/home',
#       'expanded_url': 'http://www.lakedistrictweatherline.co.uk/home',
#       'indices': [86, 109],
#       'url': 'https://t.co/mjeQuy6w5g'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/DSpiAmJbkj',
#       'expanded_url': 'https://twitter.com/LakesWeather/status/839527983874523146/photo/1',
#       'id': 839527865188237314,
#       'id_str': '839527865188237314',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/C6aaJTeWQAICDwN.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aaJTeWQAICDwN.jpg',
#       'sizes': {'large': {'h': 1500, 'resize': 'fit', 'w': 2000},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/DSpiAmJbkj'}]},
#    'favorite_count': 27,
#    'favorited': False,
#    'geo': None,
#    'id': 839527983874523146,
#    'id_str': '839527983874523146',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'The cornices immediately below the summit of Helvellyn today 8th March. #summitsafely https://t.co/mjeQuy6w5g https://t.co/DSpiAmJbkj',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Nov 28 15:36:11 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Reporting winter fell top conditions on Helvellyn and other major Lake District peaks from December - Easter each year. Tweeting tips to help you #summitsafely',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'lakedistrictweatherline.co.uk',
#         'expanded_url': 'http://www.lakedistrictweatherline.co.uk',
#         'indices': [0, 23],
#         'url': 'https://t.co/AmDMw6OFtP'}]}},
#     'favourites_count': 401,
#     'follow_request_sent': None,
#     'followers_count': 8857,
#     'following': None,
#     'friends_count': 57,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 423490958,
#     'id_str': '423490958',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 125,
#     'location': 'Lake District National Park',
#     'name': 'Fell Top Assessors',
#     'notifications': None,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/371875357/29-jan-striding_edge_from_t.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/371875357/29-jan-striding_edge_from_t.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/423490958/1406280501',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/491243781065166848/ApRN41YQ_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/491243781065166848/ApRN41YQ_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'LakesWeather',
#     'statuses_count': 2879,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/AmDMw6OFtP',
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#   'text': 'RT @LakesWeather: The cornices immediately below the summit of Helvellyn today 8th March. #summitsafely https://t.co/mjeQuy6w5g https://t.c…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Dec 28 09:20:52 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Weather data for Steeple Claydon,Bucks https://t.co/weL6WyUSbQ @Robert_Norman for non weather related tweets',
#    'entities': {'description': {'urls': [{'display_url': 'is.gd/PwNCjl',
#        'expanded_url': 'http://is.gd/PwNCjl',
#        'indices': [39, 62],
#        'url': 'https://t.co/weL6WyUSbQ'}]},
#     'url': {'urls': [{'display_url': 'my.meteoware.com/261439/#/',
#        'expanded_url': 'http://my.meteoware.com/261439/#/',
#        'indices': [0, 23],
#        'url': 'https://t.co/smGbQ1BxDC'}]}},
#    'favourites_count': 31,
#    'follow_request_sent': None,
#    'followers_count': 257,
#    'following': None,
#    'friends_count': 357,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2945576998,
#    'id_str': '2945576998',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 16,
#    'location': 'Steeple Claydon',
#    'name': 'Claydon weather',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2945576998/1427995095',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/637893529931509760/8OffFQ3R_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/637893529931509760/8OffFQ3R_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'S_C_weather',
#    'statuses_count': 18605,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': 'https://t.co/smGbQ1BxDC',
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:47 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 258195234,
#      'id_str': '258195234',
#      'indices': [3, 13],
#      'name': 'Addie Cook',
#      'screen_name': 'amcook122'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542933313499140,
#   'id_str': '839542933313499140',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 08 17:19:06 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 839525897556410368,
#    'id_str': '839525897556410368',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'God: Let there be tolerable weather! \nSatan: And with that tolerable weather let there be 50 MPH WINDS LOL',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Feb 27 04:50:09 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Supporter of musicals, dogs, pasta, art, the Oxford comma, sky watching, and Disney.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4853,
#     'follow_request_sent': None,
#     'followers_count': 241,
#     'following': None,
#     'friends_count': 282,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 258195234,
#     'id_str': '258195234',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Addie Cook',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/258195234/1475111487',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/826815352520728578/urrL9Lju_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826815352520728578/urrL9Lju_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'amcook122',
#     'statuses_count': 539,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -21600,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @amcook122: God: Let there be tolerable weather! \nSatan: And with that tolerable weather let there be 50 MPH WINDS LOL',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jan 10 02:35:04 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "it's the little things",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'daniemaria514.tumblr.com',
#        'expanded_url': 'http://daniemaria514.tumblr.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/9jkYg1imr3'}]}},
#    'favourites_count': 12578,
#    'follow_request_sent': None,
#    'followers_count': 482,
#    'following': None,
#    'friends_count': 268,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 103454755,
#    'id_str': '103454755',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'McCordsville, IN',
#    'name': 'dani💞',
#    'notifications': None,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/883587902/23c4bfa88a04a9a8b87f5d8ea1486c23.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/883587902/23c4bfa88a04a9a8b87f5d8ea1486c23.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/103454755/1483392382',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817071250375929856/6Y9znwHA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817071250375929856/6Y9znwHA_normal.jpg',
#    'profile_link_color': 'F348FE',
#    'profile_sidebar_border_color': 'F348FE',
#    'profile_sidebar_fill_color': 'FBCBFE',
#    'profile_text_color': '139EFB',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'DanieMaria514',
#    'statuses_count': 23866,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/9jkYg1imr3',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:46 +0000 2017',
#   'entities': {'hashtags': [{'indices': [18, 26], 'text': 'Clifton'},
#     {'indices': [27, 38], 'text': 'Suspension'},
#     {'indices': [39, 46], 'text': 'Bridge'},
#     {'indices': [54, 59], 'text': 'mist'},
#     {'indices': [67, 74], 'text': 'iphone'},
#     {'indices': [75, 83], 'text': 'bristol'},
#     {'indices': [84, 92], 'text': 'weather'},
#     {'indices': [93, 104], 'text': 'stormangus'},
#     {'indices': [105, 112], 'text': 'autumn'},
#     {'indices': [113, 118], 'text': 'fall'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 312718994,
#      'id_str': '312718994',
#      'indices': [3, 16],
#      'name': 'Warwick Sloss',
#      'screen_name': 'WarwickSloss'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542925713424405,
#   'id_str': '839542925713424405',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 6,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 21 18:15:42 +0000 2016',
#    'entities': {'hashtags': [{'indices': [0, 8], 'text': 'Clifton'},
#      {'indices': [9, 20], 'text': 'Suspension'},
#      {'indices': [21, 28], 'text': 'Bridge'},
#      {'indices': [36, 41], 'text': 'mist'},
#      {'indices': [49, 56], 'text': 'iphone'},
#      {'indices': [57, 65], 'text': 'bristol'},
#      {'indices': [66, 74], 'text': 'weather'},
#      {'indices': [75, 86], 'text': 'stormangus'},
#      {'indices': [87, 94], 'text': 'autumn'},
#      {'indices': [95, 100], 'text': 'fall'}],
#     'media': [{'display_url': 'pic.twitter.com/0vXJOgSU9W',
#       'expanded_url': 'https://twitter.com/WarwickSloss/status/800764639894081537/photo/1',
#       'id': 800764631916613633,
#       'id_str': '800764631916613633',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/media/CxzjMKoWEAEBA6s.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CxzjMKoWEAEBA6s.jpg',
#       'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/0vXJOgSU9W'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/0vXJOgSU9W',
#       'expanded_url': 'https://twitter.com/WarwickSloss/status/800764639894081537/photo/1',
#       'id': 800764631916613633,
#       'id_str': '800764631916613633',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/media/CxzjMKoWEAEBA6s.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/CxzjMKoWEAEBA6s.jpg',
#       'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/0vXJOgSU9W'}]},
#    'favorite_count': 21,
#    'favorited': False,
#    'geo': None,
#    'id': 800764639894081537,
#    'id_str': '800764639894081537',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 6,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '#Clifton #Suspension #Bridge in the #mist today.\n#iphone #bristol #weather #stormangus #autumn #fall https://t.co/0vXJOgSU9W',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 07 15:22:25 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Tallest wildlife-specific TV cameraman in the world, analogue B&W photographer, darkroom fiddler, toilet humorist and sweary misanthrope.\nI don't follow cats.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'sloss.co.uk',
#         'expanded_url': 'http://www.sloss.co.uk',
#         'indices': [0, 23],
#         'url': 'https://t.co/JMSavtgSRH'}]}},
#     'favourites_count': 1759,
#     'follow_request_sent': None,
#     'followers_count': 2106,
#     'following': None,
#     'friends_count': 200,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 312718994,
#     'id_str': '312718994',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Bristol and Somerset, UK',
#     'name': 'Warwick Sloss',
#     'notifications': None,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/312718994/1404371123',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/784313216708915200/4pEvhigX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/784313216708915200/4pEvhigX_normal.jpg',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'WarwickSloss',
#     'statuses_count': 5812,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/JMSavtgSRH',
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': 'RT @WarwickSloss: #Clifton #Suspension #Bridge in the #mist today.\n#iphone #bristol #weather #stormangus #autumn #fall https://t.co/0vXJOgS…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Nov 11 20:33:19 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Official site of Clifton Suspension Bridge Trust.  Follow us for our latest news & amazing visitor photos. See /brunelsbridge on Facebook for project updates.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'cliftonbridge.org.uk',
#        'expanded_url': 'http://www.cliftonbridge.org.uk',
#        'indices': [0, 22],
#        'url': 'http://t.co/LnSb2ILnbI'}]}},
#    'favourites_count': 71,
#    'follow_request_sent': None,
#    'followers_count': 6157,
#    'following': None,
#    'friends_count': 316,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 89275162,
#    'id_str': '89275162',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 161,
#    'location': 'Bristol UK',
#    'name': 'Clifton Susp Bridge',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/58331944/AerialOct06_3sm.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/58331944/AerialOct06_3sm.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/89275162/1463316901',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1534127266/CSB_1865_P04_SM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1534127266/CSB_1865_P04_SM_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'brunelsbridge',
#    'statuses_count': 4003,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': 'http://t.co/LnSb2ILnbI',
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:44 +0000 2017',
#   'entities': {'hashtags': [{'indices': [112, 119], 'text': 'tigers'},
#     {'indices': [120, 127], 'text': 'bigkid'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3281219354,
#      'id_str': '3281219354',
#      'indices': [3, 18],
#      'name': 'Stacie Gilmore',
#      'screen_name': 'SGilmoreDist11'},
#     {'id': 20440823,
#      'id_str': '20440823',
#      'indices': [48, 58],
#      'name': 'Denver Zoo',
#      'screen_name': 'DenverZoo'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542918532714496,
#   'id_str': '839542918532714496',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 08 16:38:07 +0000 2017',
#    'entities': {'hashtags': [{'indices': [92, 99], 'text': 'tigers'},
#      {'indices': [100, 107], 'text': 'bigkid'}],
#     'media': [{'display_url': 'pic.twitter.com/1EfJUAyswL',
#       'expanded_url': 'https://twitter.com/SGilmoreDist11/status/839515585818017792/photo/1',
#       'id': 839515316375826432,
#       'id_str': '839515316375826432',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/C6aOu3gUsAA5d-g.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aOu3gUsAA5d-g.jpg',
#       'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/1EfJUAyswL'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 20440823,
#       'id_str': '20440823',
#       'indices': [28, 38],
#       'name': 'Denver Zoo',
#       'screen_name': 'DenverZoo'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/1EfJUAyswL',
#       'expanded_url': 'https://twitter.com/SGilmoreDist11/status/839515585818017792/photo/1',
#       'id': 839515316375826432,
#       'id_str': '839515316375826432',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/C6aOu3gUsAA5d-g.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aOu3gUsAA5d-g.jpg',
#       'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#        'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/1EfJUAyswL'},
#      {'display_url': 'pic.twitter.com/1EfJUAyswL',
#       'expanded_url': 'https://twitter.com/SGilmoreDist11/status/839515585818017792/photo/1',
#       'id': 839515316522627072,
#       'id_str': '839515316522627072',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/C6aOu4DUsAAJUDl.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aOu4DUsAAJUDl.jpg',
#       'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1536},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#        'small': {'h': 680, 'resize': 'fit', 'w': 510},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/1EfJUAyswL'}]},
#    'favorite_count': 12,
#    'favorited': False,
#    'geo': None,
#    'id': 839515585818017792,
#    'id_str': '839515585818017792',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': {'attributes': {},
#     'bounding_box': {'coordinates': [[[-105.109815, 39.614151],
#        [-104.734372, 39.614151],
#        [-104.734372, 39.812975],
#        [-105.109815, 39.812975]]],
#      'type': 'Polygon'},
#     'contained_within': [],
#     'country': 'United States',
#     'country_code': 'US',
#     'full_name': 'Denver, CO',
# ...
#    'id_str': '2216729217',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'joie stabile',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2216729217/1447428164',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/656888769702985728/PjdjNtZr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/656888769702985728/PjdjNtZr_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'StabileJoie',
#    'statuses_count': 1119,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:37 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'rdo.to/TIKIMAN',
#      'expanded_url': 'http://rdo.to/TIKIMAN',
#      'indices': [31, 54],
#      'url': 'https://t.co/9QguO0wzl8'}],
#    'user_mentions': [{'id': 770618163713019906,
#      'id_str': '770618163713019906',
#      'indices': [55, 68],
#      'name': 'Danny Lynn',
#      'screen_name': 'TikiManRadio'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542888375730179,
#   'id_str': '839542888375730179',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.securenetsystems.net" rel="nofollow">Securenet Systems Radio Playlist Update</a>',
#   'text': 'Massive Attack - Weather Storm https://t.co/9QguO0wzl8 @tikimanradio',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Aug 30 13:44:22 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Tiki Man Radio \nYour Trop Rock Paradise',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'tikimanradio.com',
#        'expanded_url': 'http://tikimanradio.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/0NkMTnKXc1'}]}},
#    'favourites_count': 18,
#    'follow_request_sent': None,
#    'followers_count': 165,
#    'following': None,
#    'friends_count': 303,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 770618163713019906,
#    'id_str': '770618163713019906',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': '',
#    'name': 'Danny Lynn',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/770618163713019906/1472568330',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/800188587409084416/VDn2P4fT_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800188587409084416/VDn2P4fT_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TikiManRadio',
#    'statuses_count': 61541,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/0NkMTnKXc1',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:36 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/eAVx60Dht2',
#      'expanded_url': 'https://twitter.com/Kyle_Lantz/status/839506232977289216/photo/1',
#      'id': 839506229336616960,
#      'id_str': '839506229336616960',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#      'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 382},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 839506232977289216,
#      'source_status_id_str': '839506232977289216',
#      'source_user_id': 2542537892,
#      'source_user_id_str': '2542537892',
#      'type': 'photo',
#      'url': 'https://t.co/eAVx60Dht2'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2542537892,
#      'id_str': '2542537892',
#      'indices': [3, 14],
#      'name': 'Kyle Lantz',
#      'screen_name': 'Kyle_Lantz'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/eAVx60Dht2',
#      'expanded_url': 'https://twitter.com/Kyle_Lantz/status/839506232977289216/photo/1',
#      'id': 839506229336616960,
#      'id_str': '839506229336616960',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#      'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 382},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 839506232977289216,
#      'source_status_id_str': '839506232977289216',
#      'source_user_id': 2542537892,
#      'source_user_id_str': '2542537892',
#      'type': 'photo',
#      'url': 'https://t.co/eAVx60Dht2'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542887075430400,
#   'id_str': '839542887075430400',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 6,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 08 16:00:57 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/eAVx60Dht2',
#       'expanded_url': 'https://twitter.com/Kyle_Lantz/status/839506232977289216/photo/1',
#       'id': 839506229336616960,
#       'id_str': '839506229336616960',
#       'indices': [76, 99],
#       'media_url': 'http://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/eAVx60Dht2'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/eAVx60Dht2',
#       'expanded_url': 'https://twitter.com/Kyle_Lantz/status/839506232977289216/photo/1',
#       'id': 839506229336616960,
#       'id_str': '839506229336616960',
#       'indices': [76, 99],
#       'media_url': 'http://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6aGd7pWMAADqYT.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/eAVx60Dht2'}]},
#    'favorite_count': 11,
#    'favorited': False,
#    'geo': None,
#    'id': 839506232977289216,
#    'id_str': '839506232977289216',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 6,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "If this doesn't represent NC weather in one picture, I don't know what will https://t.co/eAVx60Dht2",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 03 01:31:10 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Going to give all of the glory to Him! Wingate '19",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4005,
#     'follow_request_sent': None,
#     'followers_count': 587,
#     'following': None,
#     'friends_count': 567,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 2542537892,
#     'id_str': '2542537892',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': 'WU ',
#     'name': 'Kyle Lantz',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2542537892/1481641867',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/826574432294563843/WZS8QnPX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826574432294563843/WZS8QnPX_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Kyle_Lantz',
#     'statuses_count': 3612,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @Kyle_Lantz: If this doesn't represent NC weather in one picture, I don't know what will https://t.co/eAVx60Dht2",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun May 22 23:08:36 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I'm a happy girl ✨ #Wingate17 #WUWBB",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 9186,
#    'follow_request_sent': None,
#    'followers_count': 832,
#    'following': None,
#    'friends_count': 716,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 303478232,
#    'id_str': '303478232',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4,
#    'location': '',
#    'name': 'Janna Johnson',
#    'notifications': None,
#    'profile_background_color': 'DBE9ED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/303478232/1373038172',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/833479968613134340/oRLtZ0OF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833479968613134340/oRLtZ0OF_normal.jpg',
#    'profile_link_color': 'CC3366',
#    'profile_sidebar_border_color': 'DBE9ED',
#    'profile_sidebar_fill_color': 'E6F6F9',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'jjthebanana',
#    'statuses_count': 12140,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 08 18:26:36 +0000 2017',
#   'entities': {'hashtags': [{'indices': [4, 11], 'text': 'London'},
#     {'indices': [14, 30], 'text': 'SmallBusinesses'}],
#    'symbols': [],
#    'urls': [{'display_url': 'dld.bz/f4BZh',
#      'expanded_url': 'http://dld.bz/f4BZh',
#      'indices': [78, 101],
#      'url': 'https://t.co/GIEnzS6Nw0'}],
#    'user_mentions': [{'id': 1970207377,
#      'id_str': '1970207377',
#      'indices': [106, 115],
#      'name': 'SMBCEO',
#      'screen_name': 'smbizceo'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839542883711594497,
#   'id_str': '839542883711594497',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://www.socialoomph.com" rel="nofollow">SocialOomph</a>',
#   'text': "Can #London's #SmallBusinesses Weather The Storm Of Business Rates Increases? https://t.co/GIEnzS6Nw0 via @smbizceo",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Nov 29 12:40:21 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'http://t.co/jxycmIwJ is a small business online magazine offering tips on how to turn your ideas and plans into reality.',
#    'entities': {'description': {'urls': [{'display_url': 'BizPenguin.com',
#        'expanded_url': 'http://www.BizPenguin.com',
#        'indices': [0, 20],
#        'url': 'http://t.co/jxycmIwJ'}]},
#     'url': {'urls': [{'display_url': 'bizpenguin.com',
#        'expanded_url': 'http://www.bizpenguin.com',
#        'indices': [0, 20],
#        'url': 'http://t.co/TphdL5Hm'}]}},
#    'favourites_count': 7,
#    'follow_request_sent': None,
#    'followers_count': 1187,
#    'following': None,
#    'friends_count': 790,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 978260670,
#    'id_str': '978260670',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 790,
#    'location': '',
#    'name': 'Biz Penguin',
#    'notifications': None,
#    'profile_background_color': 'FF4000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/978260670/1429957052',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2916934832/da16548035539ffea31ae0aed356c444_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2916934832/da16548035539ffea31ae0aed356c444_normal.png',
#    'profile_link_color': 'FF4000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BizPenguin',
#    'statuses_count': 18817,
#    'time_zone': 'Bangkok',
#    'translator_type': 'none',
#    'url': 'http://t.co/TphdL5Hm',
#    'utc_offset': 25200,
#    'verified': False}}]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8a82c8a18ac6> in <module>()
# ----> 1 len(get_tweets_by_location)
#
# TypeError: object of type 'function' has no len()

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 240
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 60
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 20 new tweets, for a total of 20
# At 60 seconds, added 20 new tweets, for a total of 40
# At 120 seconds, added 20 new tweets, for a total of 60
# At 180 seconds, added 20 new tweets, for a total of 80
# 80 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 836962073192038401  836962073192038401  None  None
# 836962055714402304  836962055714402304  None  None
# 836962042477219840  836962042477219840  None  None
# 836962039847247872  836962039847247872  None  None
# 836962037263654913  836962037263654913  None  None
# 836962036630302720  836962036630302720  None  None
# 836962035669823489  836962035669823489  None  None
# 836962019794423808  836962019794423808  None  None
# 836962018892591104  836962018892591104  None  None
# 836962016845791232  836962016845791232  None  None
# 836962012450127872  836962012450127872  None  None
# 836962010453671937  836962010453671937  None  None
# 836962006976630784  836962006976630784  None  None
# 836962005177286656  836962005177286656  None  None
# 836962004715864064  836962004715864064  None  None
#
#                                                               content  \
# 836962073192038401  Rapid prototyping using @extraordinaires with ...
# 836962055714402304  #keepitlocked N/P: Jonn Hart ft @FrencHMonTanA...
# 836962042477219840  Review: “The Student-Athlete &amp; College Rec...
# 836962039847247872  RT @realJeffreyLord: Trump critic Van Jones: ‘...
# 836962037263654913  RT @TheRealLmape: LACK OF COMMUNICATION LEAVES...
# 836962036630302720  RT @HersheyCompany: "I'm confident that our co...
# 836962035669823489  @sgreenstonenj Okay, I'll give that a shot. Th...
# 836962019794423808  #LancasterCO MDJ Rodney Hartman to leave New H...
# 836962018892591104  The Best Artists to Listen to When Having Rela...
# 836962016845791232  @CNNPolitics what so then you can blame the Re...
# 836962012450127872  Trans youth in Pennsylvania need your help. ht...
# 836962010453671937                            https://t.co/C8rCbRTQq5
# 836962006976630784  There are many things from West Wing that have...
# 836962005177286656  I posted a new photo to Facebook https://t.co/...
# 836962004715864064  Women In Business Advice for Today\nYou Can’t ...
#
#                               location                user  \
# 836962073192038401                               374663510
# 836962055714402304      Harrisburg Pa.           867943633
# 836962042477219840        Carlisle, PA           136372004
# 836962039847247872                 USA  796414862167568384
# 836962037263654913                      796128556396875776
# 836962036630302720         Hershey, PA            29347671
# 836962035669823489      Harrisburg, PA          3185568314
# 836962019794423808      Harrisburg, PA           130917318
# 836962018892591104      Harrisburg, PA            33578280
# 836962016845791232      Middletown, PA  808728888264314880
# 836962012450127872      Harrisburg, PA            28481437
# 836962010453671937  Camp Hill, PA, USA            13218762
# 836962006976630784      Harrisburg, PA            40145940
# 836962005177286656        Carlisle, PA          3142570386
# 836962004715864064            York, PA           114675893
#
#                                                            raw_source  \
# 836962073192038401  {'created_at': 'Wed Mar 01 15:31:22 +0000 2017...
# 836962055714402304  {'created_at': 'Wed Mar 01 15:31:18 +0000 2017...
# 836962042477219840  {'created_at': 'Wed Mar 01 15:31:15 +0000 2017...
# 836962039847247872  {'created_at': 'Wed Mar 01 15:31:14 +0000 2017...
# 836962037263654913  {'created_at': 'Wed Mar 01 15:31:14 +0000 2017...
# 836962036630302720  {'created_at': 'Wed Mar 01 15:31:14 +0000 2017...
# 836962035669823489  {'created_at': 'Wed Mar 01 15:31:13 +0000 2017...
# 836962019794423808  {'created_at': 'Wed Mar 01 15:31:10 +0000 2017...
# 836962018892591104  {'created_at': 'Wed Mar 01 15:31:09 +0000 2017...
# 836962016845791232  {'created_at': 'Wed Mar 01 15:31:09 +0000 2017...
# 836962012450127872  {'created_at': 'Wed Mar 01 15:31:08 +0000 2017...
# 836962010453671937  {'created_at': 'Wed Mar 01 15:31:07 +0000 2017...
# 836962006976630784  {'created_at': 'Wed Mar 01 15:31:07 +0000 2017...
# 836962005177286656  {'created_at': 'Wed Mar 01 15:31:06 +0000 2017...
# 836962004715864064  {'created_at': 'Wed Mar 01 15:31:06 +0000 2017...
#
#                    data_point                            time
# 836962073192038401       none  Wed Mar 01 15:31:22 +0000 2017
# 836962055714402304       none  Wed Mar 01 15:31:18 +0000 2017
# 836962042477219840       none  Wed Mar 01 15:31:15 +0000 2017
# 836962039847247872       none  Wed Mar 01 15:31:14 +0000 2017
# 836962037263654913       none  Wed Mar 01 15:31:14 +0000 2017
# 836962036630302720       none  Wed Mar 01 15:31:14 +0000 2017
# 836962035669823489       none  Wed Mar 01 15:31:13 +0000 2017
# 836962019794423808       none  Wed Mar 01 15:31:10 +0000 2017
# 836962018892591104       none  Wed Mar 01 15:31:09 +0000 2017
# 836962016845791232       none  Wed Mar 01 15:31:09 +0000 2017
# 836962012450127872       none  Wed Mar 01 15:31:08 +0000 2017
# 836962010453671937       none  Wed Mar 01 15:31:07 +0000 2017
# 836962006976630784       none  Wed Mar 01 15:31:07 +0000 2017
# 836962005177286656       none  Wed Mar 01 15:31:06 +0000 2017
# 836962004715864064       none  Wed Mar 01 15:31:06 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['', 'Harrisburg Pa.', 'Carlisle, PA', 'USA', 'Hershey, PA',
#        'Harrisburg, PA', 'Middletown, PA', 'Camp Hill, PA, USA', 'York, PA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                     Count
# Location
#                         2
# Camp Hill, PA, USA      1
# Carlisle, PA            2
# Harrisburg Pa.          1
# Harrisburg, PA          5
# Hershey, PA             1
# Middletown, PA          1
# USA                     1
# York, PA                1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# /Users/mjfoster/anaconda/envs/python3/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/mjfoster/anaconda/envs/python3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/mjfoster/anaconda/envs/python3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# /Users/mjfoster/anaconda/envs/python3/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 30 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
